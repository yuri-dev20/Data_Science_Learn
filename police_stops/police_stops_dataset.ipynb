# %% [markdown]
# # Exploratory Data Analisys with Pandas
#
# The purpose of the following notebook is to do a basic EDA Police Stops dataset from Stanford Open Policing Project
# wich can be found here: https://openpolicing.stanford.edu/data/

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('./dataset/ca_san_diego_2020_04_01.csv')

# %%
# Display first 5 rows
df.dropna().head(5)
# Out:
#     raw_row_number        date      time service_area  subject_age  \
# 80              82  2014-01-02  13:30:00      Unknown         25.0
# 127            131  2014-01-03  06:50:00          310         28.0
# 171            177  2014-01-03  18:50:00          810         27.0
# 221            227  2014-01-04  07:35:00          310         36.0
# 295            302  2014-01-05  02:30:00          240         23.0
#
#                subject_race subject_sex       type arrest_made  \
# 80                 hispanic        male  vehicular       False
# 127                hispanic        male  vehicular       False
# 171                hispanic      female  vehicular       False
# 221                   white        male  vehicular       False
# 295  asian/pacific islander        male  vehicular       False
#
#     citation_issued  ...   outcome contraband_found search_conducted  \
# 80            False  ...   warning             True             True
# 127            True  ...  citation            False             True
# 171            True  ...  citation            False             True
# 221            True  ...  citation             True             True
# 295           False  ...   warning            False             True
#
#      search_person search_vehicle    search_basis  \
# 80           False           True  probable cause
# 127          False           True           other
# 171           True          False           other
# 221          False           True         consent
# 295           True          False         consent
#
#                        reason_for_search      reason_for_stop  \
# 80                    Odor of Contraband     Moving Violation
# 127                     Inventory Search     Moving Violation
# 171  Inventory Search [Prior to Impound]  Equipment Violation
# 221                       Consent Search  Equipment Violation
# 295                       Consent Search  Equipment Violation
#
#       raw_action_taken raw_subject_race_description
# 80   Verbal Warning|FI                     HISPANIC
# 127           Citation                     HISPANIC
# 171           Citation                     HISPANIC
# 221           Citation                        WHITE
# 295  Verbal Warning|FI                  OTHER ASIAN
#
# [5 rows x 21 columns]

# %%
# Display last 5 rows
df.tail(5)
# Out:
#                                            raw_row_number        date time  \
# 383022  22328|23428|25249|37956|58992|60924|62384|1134...         NaN  NaN
# 383023                                       88615|178144         NaN  NaN
# 383024                                             141559  2014-12-22  NaN
# 383025                                       72218|164647         NaN  NaN
# 383026  35299|35770|37955|51788|68873|131546|150205|16...         NaN  NaN
#
#        service_area  subject_age subject_race subject_sex       type  \
# 383022          620          NaN          NaN         NaN  vehicular
# 383023          710          NaN          NaN         NaN  vehicular
# 383024          720          NaN          NaN         NaN  vehicular
# 383025          810          NaN          NaN         NaN  vehicular
# 383026      Unknown          NaN          NaN         NaN  vehicular
#
#        arrest_made citation_issued  ...   outcome contraband_found  \
# 383022         NaN            True  ...  citation              NaN
# 383023         NaN            True  ...  citation              NaN
# 383024       False            True  ...  citation              NaN
# 383025         NaN            True  ...  citation              NaN
# 383026         NaN            True  ...  citation              NaN
#
#        search_conducted  search_person search_vehicle search_basis  \
# 383022            False          False          False          NaN
# 383023            False          False          False          NaN
# 383024            False          False          False          NaN
# 383025            False          False          False          NaN
# 383026            False          False          False          NaN
#
#        reason_for_search                                    reason_for_stop  \
# 383022               NaN  NA|Equipment Violation|NA|NA|NA|NA|NA|Moving V...
# 383023               NaN                                NA|Moving Violation
# 383024               NaN                                   Moving Violation
# 383025               NaN                                   Moving Violation
# 383026               NaN  Moving Violation|Moving Violation|Moving Viola...
#
#                                          raw_action_taken  \
# 383022  Verbal Warning|NA|Citation|Citation|NA|NA|NA|C...
# 383023                                        NA|Citation
# 383024                                           Citation
# 383025                                        Citation|NA
# 383026    NA|NA|NA|NA|Citation|Citation|NA|Citation|NA|NA
#
#        raw_subject_race_description
# 383022                          NaN
# 383023                          NaN
# 383024                          NaN
# 383025                          NaN
# 383026                          NaN
#
# [5 rows x 21 columns]

# %%
# How many rows and columns
df.shape
# Out:
# (383027, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383027 entries, 0 to 383026
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   raw_row_number                383027 non-null  object
#  1   date                          382844 non-null  object
#  2   time                          382292 non-null  object
#  3   service_area                  383027 non-null  object
#  4   subject_age                   371064 non-null  float64
#  5   subject_race                  381793 non-null  object
#  6   subject_sex                   382366 non-null  object
#  7   type                          383027 non-null  object
#  8   arrest_made                   348284 non-null  object
#  9   citation_issued               351056 non-null  object
#  10  warning_issued                351056 non-null  object
#  11  outcome                       343855 non-null  object
#  12  contraband_found              16288 non-null   object
#  13  search_conducted              383027 non-null  bool
#  14  search_person                 380837 non-null  object
#  15  search_vehicle                380837 non-null  object
#  16  search_basis                  16288 non-null   object
#  17  reason_for_search             14278 non-null   object
#  18  reason_for_stop               382808 non-null  object
#  19  raw_action_taken              351056 non-null  object
#  20  raw_subject_race_description  381793 non-null  object
# dtypes: bool(1), float64(1), object(19)
# memory usage: 58.8+ MB

# %%
# Gives a Descrptive Statistics summary
df.describe(include="all")
# Out:
#        raw_row_number        date      time service_area    subject_age  \
# count          383027      382844    382292       383027  371064.000000
# unique         383027        1186      1440           25            NaN
# top                 1  2014-02-05  22:00:00          310            NaN
# freq                1         853      2737        31511            NaN
# mean              NaN         NaN       NaN          NaN      37.095956
# std               NaN         NaN       NaN          NaN      14.183295
# min               NaN         NaN       NaN          NaN      10.000000
# 25%               NaN         NaN       NaN          NaN      25.000000
# 50%               NaN         NaN       NaN          NaN      34.000000
# 75%               NaN         NaN       NaN          NaN      47.000000
# max               NaN         NaN       NaN          NaN     100.000000
#
#        subject_race subject_sex       type arrest_made citation_issued  ...  \
# count        381793      382366     383027      348284          351056  ...
# unique            5           2          1           2               2  ...
# top           white        male  vehicular       False            True  ...
# freq         162226      248398     383027      343469          221137  ...
# mean            NaN         NaN        NaN         NaN             NaN  ...
# std             NaN         NaN        NaN         NaN             NaN  ...
# min             NaN         NaN        NaN         NaN             NaN  ...
# 25%             NaN         NaN        NaN         NaN             NaN  ...
# 50%             NaN         NaN        NaN         NaN             NaN  ...
# 75%             NaN         NaN        NaN         NaN             NaN  ...
# max             NaN         NaN        NaN         NaN             NaN  ...
#
#          outcome contraband_found search_conducted search_person  \
# count     343855            16288           383027        380837
# unique         3                2                2             2
# top     citation            False            False         False
# freq      219712            14735           366739        373413
# mean         NaN              NaN              NaN           NaN
# std          NaN              NaN              NaN           NaN
# min          NaN              NaN              NaN           NaN
# 25%          NaN              NaN              NaN           NaN
# 50%          NaN              NaN              NaN           NaN
# 75%          NaN              NaN              NaN           NaN
# max          NaN              NaN              NaN           NaN
#
#        search_vehicle search_basis                    reason_for_search  \
# count          380837        16288                                14278
# unique              2            5                                  632
# top             False        other  Inventory Search [Prior to Impound]
# freq           370738        10855                                 4024
# mean              NaN          NaN                                  NaN
# std               NaN          NaN                                  NaN
# min               NaN          NaN                                  NaN
# 25%               NaN          NaN                                  NaN
# 50%               NaN          NaN                                  NaN
# 75%               NaN          NaN                                  NaN
# max               NaN          NaN                                  NaN
#
#          reason_for_stop raw_action_taken raw_subject_race_description
# count             382808           351056                       381793
# unique                97              166                           18
# top     Moving Violation         Citation                        WHITE
# freq              279839           216258                       162226
# mean                 NaN              NaN                          NaN
# std                  NaN              NaN                          NaN
# min                  NaN              NaN                          NaN
# 25%                  NaN              NaN                          NaN
# 50%                  NaN              NaN                          NaN
# 75%                  NaN              NaN                          NaN
# max                  NaN              NaN                          NaN
#
# [11 rows x 21 columns]

# %%
# Simple way to get columns to perform different analisys and stuff
df.columns
# Out:
# Index(['raw_row_number', 'date', 'time', 'service_area', 'subject_age',
#        'subject_race', 'subject_sex', 'type', 'arrest_made', 'citation_issued',
#        'warning_issued', 'outcome', 'contraband_found', 'search_conducted',
#        'search_person', 'search_vehicle', 'search_basis', 'reason_for_search',
#        'reason_for_stop', 'raw_action_taken', 'raw_subject_race_description'],
#       dtype='object')

# %%
print("Quantity of null/nan values: ", df.isnull().sum().sum())
# Out:
# Quantity of null/nan values:  1292664

# %%
df["contraband_found"].value_counts()
# Out:
# contraband_found
# False    14735
# True      1553
# Name: count, dtype: int64

# %%
df["raw_subject_race_description"].value_counts()
# Out:
# raw_subject_race_description
# WHITE               162226
# HISPANIC            117083
# BLACK                42705
# OTHER                27238
# OTHER ASIAN          17811
# FILIPINO              5162
# VIETNAMESE            2862
# CHINESE               2090
# INDIAN                1976
# KOREAN                 563
# JAPANESE               477
# PACIFIC ISLANDER       425
# ASIAN INDIAN           310
# LAOTIAN                284
# SAMOAN                 218
# CAMBODIAN              200
# GUAMANIAN              107
# HAWAIIAN                56
# Name: count, dtype: int64

# %%
plt.ylabel("Sex")
plt.xlabel("Values based of")
plt.grid()
sns.countplot(df["subject_sex"], palette="flare")
# Out:
# C:\Users\yurig\AppData\Local\Temp\ipykernel_8880\1277813844.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df["subject_sex"], palette="flare")
# <Axes: xlabel='Values based of', ylabel='Sex'>

# %%
plt.ylabel("Driver race")
plt.xlabel("Quantity of stops")
plt.grid()
sns.barplot(df["subject_race"].dropna().value_counts(), orient="h", palette="flare")
# Out:
# C:\Users\yurig\AppData\Local\Temp\ipykernel_8880\2793204225.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(df["subject_race"].dropna().value_counts(), orient="h", palette="flare")
# <Axes: xlabel='Quantity of stops', ylabel='Driver race'>

# %%
plt.ylabel("Driver Age")
plt.xlabel("Quantity of stops of the first 5")
plt.grid()
sns.barplot(df["subject_age"].dropna().value_counts().head(5), orient="h")
# Out:
# <Axes: xlabel='Quantity of stops of the first 5', ylabel='Driver Age'>
